# %% [markdown]
# <h2 style="color:green" align="center">logistic regression: Binary classification</h2>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.shape
# Out:
# (27, 2)

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
 y_train
# Out:
# 3     0
# 20    0
# 4     1
# 0     0
# 12    0
# 9     1
# 1     0
# 11    0
# 18    0
# 2     1
# 5     1
# 7     1
# 25    1
# 24    1
# 14    1
# 6     0
# 16    1
# 26    0
# 17    1
# 10    0
# 8     1
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 15   55
# 22   40
# 19   18
# 21   26
# 13   29
# 23   45

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0, 0, 0, 0, 1])

# %%
y_test
# Out:
# 15    1
# 22    1
# 19    0
# 21    0
# 13    0
# 23    1
# Name: bought_insurance, dtype: int64

# %%
model.predict_proba(X_test)
# Out:
# array([[0.14607798, 0.85392202],
#        [0.50337865, 0.49662135],
#        [0.93232905, 0.06767095],
#        [0.84212364, 0.15787636],
#        [0.78889404, 0.21110596],
#        [0.35903464, 0.64096536]])

# %% [markdown]
# **model.coef_ indicates value of m in y=m*x + b equation**

# %%
model.coef_
# Out:
# array([[0.11861428]])

# %% [markdown]
# **model.intercept_ indicates value of b in y=m*x + b equation**

# %%
model.intercept_
# Out:
# array([-4.75808585])

# %%
# Imports: tools we need for evaluation + plotting

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

# %%
y_pred.shape
# Out:
# (6,)

# %%
y_test.shape
# Out:
# (6,)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[3, 0],
#        [1, 2]])

# %%
# Plot Confusion Matrix
# This draws a nice figure.

disp = ConfusionMatrixDisplay(confusion_matrix=cm)

plt.figure(figsize=(6, 5))
disp.plot(values_format="d")   # "d" means show integers
plt.title("Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.88      0.83      0.83         6
# weighted avg       0.88      0.83      0.83         6
